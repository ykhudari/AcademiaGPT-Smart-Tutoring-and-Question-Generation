# %%
import pandas as pd
import sqlalchemy as sa

url = "postgresql://postgres:password@192.168.0.77:25432/postgres"

conn = sa.create_engine(url)

df = pd.read_sql("select uuid, cmetadata from langchain_pg_embedding", conn)

# %%
df.cmetadata.apply(lambda x: x["source"]).value_counts().to_csv("metadata_source.csv")

# %%
lectures = pd.read_json("msda_test_course_contents.json")

# %%
lectures.sort_values("lecture_id")
# Out:
#      id  position        available_at  due_date  course_id  lecture_id  \
# 0   170         9 2023-09-08 12:54:25       NaN          5           6
# 1   186        10 2023-09-08 12:54:25       NaN          5           6
# 2   185         9 2023-09-08 12:54:25       NaN          5           6
# 3   157         9 2023-09-08 12:54:25       NaN          5           6
# 22  139         9 2023-09-08 12:54:25       NaN          5           7
# 23  144        10 2023-09-08 12:54:25       NaN          5           7
# 24  156         9 2023-09-08 12:54:25       NaN          5           7
# 25  159         9 2023-09-08 12:54:25       NaN          5           7
# 26  151        11 2023-09-08 12:54:25       NaN          5           7
# 27  158        11 2023-09-08 12:54:25       NaN          5           7
# 20  148        11 2023-09-08 12:54:25       NaN          5           7
# 21  149        11 2023-09-08 12:54:25       NaN          5           7
# ...
